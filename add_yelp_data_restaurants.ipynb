# %% [markdown]
# # Querying Yelp API for number Expensive Restaurants

# %% [markdown]
# ### Yelp API

# %%
import pandas as pd
import requests
import json

# %%
csv = pd.read_csv('joinable_kc_dataset.csv')
df = pd.DataFrame(csv)

# %%
Client_ID = 'eTI2JFf__7F7P68gD-zn8A'
API_Key = 'TUAdGPXwwCkEmUflMxuQIfwY26xLm8yvFxTd_s3_UNwuPGtKuLZfsv057L_0otifVXMF0yJgzRnQ3jkK55nxInFi46ykSQach1iP2gYqRODoG49WiUamXiKo0e5TWnYx'
Client_Secret = 'hfKNLphbLHy32wHeYomMxmVMcIZacckdxuDNc9fViPRHSbgcxYC37gi6R8Ppv7sO'

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view                  ...                   \
# 0      5650     1.0           0     0                  ...
# 1      7242     2.0           0     0                  ...
# 2     10000     1.0           0     0                  ...
# 3      5000     1.0           0     0                  ...
# 4      8080     1.0           0     0                  ...
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# ...

# %%
df2 = pd.DataFrame()
df2['lat+long_group'] = ''
df2['Number of Expensive Restaurants'] = ''

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: [lat+long_group, Number of Expensive Restaurants]
# Index: []

# %%
df3 = df.head(5)

# %%
df3
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view                  ...                   \
# 0      5650     1.0           0     0                  ...
# 1      7242     2.0           0     0                  ...
# 2     10000     1.0           0     0                  ...
# 3      5000     1.0           0     0                  ...
# 4      8080     1.0           0     0                  ...
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# ...

# %%
# Include Yelp Token
headers = {"Authorization": "Bearer gl6k6JmewUhzjMVBv0I2x4Bz_NRiEggSqjlGbTaejmbzvBJXgI36FPgWoqBnEL9QQ6wU5H4h41dxPkxVjHFlawtH69m1kcXQuHev5PuWBtcdBEAbdJR0HNl3d4tpWXYx"}
counter = 0

# Loop through every zip code
for index, row in df.iterrows():
    
    # Add to counter
    counter = counter + 1
    
    # Create endpoint URL:
    target_url = "https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude={}&longitude={}" .format(row['lat_group'], row['long_group'])
    
    # Print the URLs to ensure logging
    print(counter)
    print(target_url)
    
    try:
        # Get the Yelp Reviews
        yelp_reviews = requests.get(target_url, headers=headers).json()
    
        # Calculate the total reviews and weighted rankings
        review_count = 0
        weighted_review = 0
    except:
        print("Couldn't get or parse response")
    
    try:
        
        # Retrieve total number of results from category search
        total = yelp_reviews['total']

        # Append the data to the appropriate column of the data frames
        df2.set_value(index, "lat+long_group", row["lat+long_group"])
        df2.set_value(index, 'Number of Expensive Restaurants', total)

    except:
        print("Couldn't retrieve total or set value")
# Out:
# 1
# https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude=47.516708035714366&longitude=-122.2529999999999
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 2
# https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude=47.716540178571556&longitude=-122.3089999999999
# 3
# https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude=47.73874375000014&longitude=-122.22499999999991
# 4
# https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude=47.516708035714366&longitude=-122.39299999999999
# ...

# %%
df2['Number of Expensive Restaurants'].sum()
# Out:
# 14747

# %%
len(df2[df2['Number of Expensive Restaurants'] > 0])
# Out:
# 6462

# %%
df2
# Out:
#                              lat+long_group Number of Expensive Restaurants
# 0      47.51670803571437,-122.2529999999999                               0
# 1      47.71654017857156,-122.3089999999999                               0
# 2      47.73874375000014,-122.2249999999999                               0
# 3                47.51670803571437,-122.393                               1
# 4      47.61662410714297,-122.0569999999999                               0
# 5      47.66103125000012,-122.0009999999999                               0
# 6      47.30577410714289,-122.3369999999999                               0
# 7      47.40569017857149,-122.3089999999999                               2
# 8      47.51670803571437,-122.3369999999999                               1
# 9      47.37238482142862,-122.0289999999999                               0
# 10     47.60552232142868,-122.1409999999999                               0
# ...

# %% [markdown]
# Got them all

# %%
df2.to_csv('yelp_restaurants.csv', index=False)

# %% [markdown]
# Next step will be to join this data with the original dataset, drop any rows with missing data, and plot the rest.
