# %% [markdown]
# # Querying Yelp API for coffee shop ratings by area

# %% [markdown]
# ### Yelp API

# %%
import pandas as pd
import requests
import json

# %%
csv = pd.read_csv('unique_latlongs.csv')
df = pd.DataFrame(csv)

# %%
Client_ID = 'eTI2JFf__7F7P68gD-zn8A'
API_Key = 'TUAdGPXwwCkEmUflMxuQIfwY26xLm8yvFxTd_s3_UNwuPGtKuLZfsv057L_0otifVXMF0yJgzRnQ3jkK55nxInFi46ykSQach1iP2gYqRODoG49WiUamXiKo0e5TWnYx'
Client_Secret = 'hfKNLphbLHy32wHeYomMxmVMcIZacckdxuDNc9fViPRHSbgcxYC37gi6R8Ppv7sO'

# %%
df.head()
# Out:
#    lat_group  long_group                        lat+long_group
# 0  47.516708    -122.253  47.51670803571437,-122.2529999999999
# 1  47.716540    -122.309  47.71654017857156,-122.3089999999999
# 2  47.738744    -122.225  47.73874375000014,-122.2249999999999
# 3  47.516708    -122.393            47.51670803571437,-122.393
# 4  47.616624    -122.057  47.61662410714297,-122.0569999999999

# %%
df2 = pd.DataFrame()
df2['lat+long_group'] = ''
df2['Review Count'] = ''
df2['Average Rating'] = ''
df2['Weighted Rating'] = ''

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: [lat+long_group, Review Count, Average Rating, Weighted Rating]
# Index: []

# %%
df3 = df.head(5)

# %%
df3
# Out:
#    lat_group  long_group                        lat+long_group
# 0  47.516708    -122.253  47.51670803571437,-122.2529999999999
# 1  47.716540    -122.309  47.71654017857156,-122.3089999999999
# 2  47.738744    -122.225  47.73874375000014,-122.2249999999999
# 3  47.516708    -122.393            47.51670803571437,-122.393
# 4  47.616624    -122.057  47.61662410714297,-122.0569999999999

# %%
# Include Yelp Token
headers = {"Authorization": "Bearer gl6k6JmewUhzjMVBv0I2x4Bz_NRiEggSqjlGbTaejmbzvBJXgI36FPgWoqBnEL9QQ6wU5H4h41dxPkxVjHFlawtH69m1kcXQuHev5PuWBtcdBEAbdJR0HNl3d4tpWXYx"}
counter = 0

# Loop through every zip code
for index, row in df.iterrows():
    
    # Add to counter
    counter = counter + 1
    
    # Create endpoint URL:
    target_url = "https://api.yelp.com/v3/businesses/search?term=Coffee&radius=1200&latitude={}&longitude={}" .format(row['lat_group'], row['long_group'])
    
    # Print the URLs to ensure logging
    print(counter)
    print(target_url)
    
    # Get the Yelp Reviews
    yelp_reviews = requests.get(target_url, headers=headers).json()
    
    # Calculate the total reviews and weighted rankings
    review_count = 0
    weighted_review = 0
    
    try:
        
        # Loop through all records to calculate the review count and weighted review value
        for business in yelp_reviews["businesses"]:

            review_count = review_count + business["review_count"]
            weighted_review = weighted_review + business["review_count"] * business["rating"]

        # Append the data to the appropriate column of the data frames
        df2.set_value(index, "lat+long_group", row["lat+long_group"])
        df2.set_value(index, "Review Count", review_count)
        df2.set_value(index, "Average Rating", weighted_review / review_count)
        df2.set_value(index, "Weighted Rating", weighted_review)

    except:
        print("Uh oh")
# Out:
# 1
# https://api.yelp.com/v3/businesses/search?term=Coffee&radius=1200&latitude=47.516708035714366&longitude=-122.2529999999999
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:36: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:37: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 2
# ...

# %%
df2
# Out:
#                          lat+long_group Review Count Average Rating  \
# 0  47.51670803571437,-122.2529999999999          591        4.08714
# 1  47.71654017857156,-122.3089999999999           76          3.625
# 2  47.73874375000014,-122.2249999999999            0            NaN
# 3            47.51670803571437,-122.393          144            4.5
# 4  47.61662410714297,-122.0569999999999            0            NaN
#
#   Weighted Rating
# 0          2415.5
# 1           275.5
# 2             NaN
# 3             648
# 4             NaN

# %%
df2
# Out:
#                            lat+long_group Review Count Average Rating  \
# 0    47.51670803571437,-122.2529999999999          709        4.15585
# 1    47.71654017857156,-122.3089999999999          471        3.32484
# 2    47.73874375000014,-122.2249999999999            0            NaN
# 3              47.51670803571437,-122.393          144            4.5
# 4    47.61662410714297,-122.0569999999999            0            NaN
# 5    47.66103125000012,-122.0009999999999            0            NaN
# 6    47.30577410714289,-122.3369999999999          190        3.28947
# 7    47.40569017857149,-122.3089999999999          260        4.11923
# 8    47.51670803571437,-122.3369999999999          329        4.48328
# 9    47.37238482142862,-122.0289999999999          520        3.93846
# 10   47.60552232142868,-122.1409999999999         1602        3.36267
# 11   47.69433660714299,-122.2809999999999          775        3.80903
# ...

# %% [markdown]
# Dang. Got 785 before hitting a snag. Got most of them at least.

# %%
df2.to_csv('most_of_yelp_coffee.csv', index=False)
