# %%
import pandas as pd
import requests
import json

# %%
csv = pd.read_csv('joinable_kc_dataset.csv')
df = pd.DataFrame(csv)

# %%
# Include Yelp Token
headers = {"Authorization": "Bearer gl6k6JmewUhzjMVBv0I2x4Bz_NRiEggSqjlGbTaejmbzvBJXgI36FPgWoqBnEL9QQ6wU5H4h41dxPkxVjHFlawtH69m1kcXQuHev5PuWBtcdBEAbdJR0HNl3d4tpWXYx"}
counter = 0
    
# Add to counter
counter = counter + 1

latitude = str(47.6221)
longitude = str(-122.325)
    
# Create endpoint URL:
target_url = "https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude={}&longitude={}" .format(latitude, longitude)
    
# Print the URLs to ensure logging
print(counter)
print(target_url)
    
try:
    # Get the Yelp Reviews
    yelp_reviews = requests.get(target_url, headers=headers).json()
    
    # Calculate the total reviews and weighted rankings
    review_count = 0
    weighted_review = 0
except:
    print("Couldn't get or parse response")
    
try:
        
    # Retrieve total number of results from category search
    total = yelp_reviews

    # Append the data to the appropriate column of the data frames
    print(json.dumps(total, indent=4, sort_keys=True))
    #print(total)

except:
    print("Couldn't retrieve total or set value")
# Out:
# 1
# https://api.yelp.com/v3/businesses/search?categories=restaurants,food&price=3,4&radius=800&latitude=47.6221&longitude=-122.325
# {
#     "businesses": [
#         {
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.62488,
#                 "longitude": -122.32115
#             },
#             "display_phone": "(206) 402-6749",
#             "distance": 411.25872592639996,
#             "id": "altura-seattle",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/GwQ7fWaoKpJeND_FXgv8Vg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "617 Broadway E",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
# ...

# %%
altura-seattle
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-12-9098c54a4367> in <module>()
# ----> 1 altura-seattle
#
# NameError: name 'altura' is not defined

# %%
# Include Yelp Token
headers = {"Authorization": "Bearer gl6k6JmewUhzjMVBv0I2x4Bz_NRiEggSqjlGbTaejmbzvBJXgI36FPgWoqBnEL9QQ6wU5H4h41dxPkxVjHFlawtH69m1kcXQuHev5PuWBtcdBEAbdJR0HNl3d4tpWXYx"}
counter = 0
    
# Add to counter
counter = counter + 1

latitude = str(47.6221)
longitude = str(-122.325)
    
# Create endpoint URL:
target_url = "https://api.yelp.com/v3/businesses/altura-seattle/reviews"
    
# Print the URLs to ensure logging
print(counter)
print(target_url)
    
try:
    # Get the Yelp Reviews
    yelp_reviews = requests.get(target_url, headers=headers, sort_by='date_asc').json()
    
    # Calculate the total reviews and weighted rankings
    review_count = 0
    weighted_review = 0
except:
    print("Couldn't get or parse response")
    
try:
        
    # Retrieve total number of results from category search
    total = yelp_reviews

    # Append the data to the appropriate column of the data frames
    print(json.dumps(total, indent=4, sort_keys=True))
    #print(total)

except:
    print("Couldn't retrieve total or set value")
# Out:
# 1
# https://api.yelp.com/v3/businesses/altura-seattle/reviews
# Couldn't get or parse response
# {
#     "possible_languages": [
#         "en"
#     ],
#     "reviews": [
#         {
#             "id": "Jf1FplGRyXEYOg-ajYsx9g",
#             "rating": 5,
#             "text": "One word to describe Altura: WOW. \n\nI'm the kind of person who spends 80% of my disposable income on food, because I strongly believe that if it doesn't...",
#             "time_created": "2018-01-12 01:16:08",
#             "url": "https://www.yelp.com/biz/altura-seattle?hrid=Jf1FplGRyXEYOg-ajYsx9g&adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=1GwZyE0zIjSujpHtlMnodQ",
#             "user": {
#                 "image_url": "https://s3-media2.fl.yelpcdn.com/photo/BHq6a5RfsTfVD1c2eyZlyw/o.jpg",
#                 "name": "Lish S."
#             }
#         },
#         {
#             "id": "usu9VMY_rQNKFUSqly4N7A",
#             "rating": 5,
# ...
